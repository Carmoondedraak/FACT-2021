# %%
#import argparse
from disentanglement.test_factorvae import plot_training_loss, plot_disentanglemet_metric, plot_experiment2, plot_disentanglemet, plot_train_loss

args = {"ckpt_dir":'./results/' ,"seeds":['seed_1','seed_2']}

# %%
# For the Experiment 1 results
args["ckpt_dir"] = './results/disent/vanilla_factorvae/'
#plot_disentanglemet_metric(args.get("ckpt_dir"), args.get("seeds"), vanilla=True)
#plot_training_loss(args.get("ckpt_dir"), args.get("seeds"), detail=True)
#args["ckpt_dir"] = './results/disent/attention_factorvae/'
#plot_disentanglemet_metric(args.get("ckpt_dir"), args.get("seeds"), vanilla=False)

# Vanilla FactorVAE
args = {"ckpt_dir":'./results/disent/vanilla_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[10,20,30,40,50], "lambdas":[], "max_iters":150000, "comp_plot":False}
plot_disentanglemet(**args)
args = {"ckpt_dir":'./results/disent/vanilla_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[10,20,30,40,50], "lambdas":[], "max_iters":150000, "detail":True}
plot_train_loss(**args)


# AD-FactorVAE
args = {"ckpt_dir":'./results/disent/attention_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[10,20,30,40,50], "lambdas":[1.0], "max_iters":150000, "comp_plot":True}
plot_disentanglemet(**args)
args = {"ckpt_dir":'./results/disent/attention_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[10,20,30,40,50], "lambdas":[1.0], "max_iters":150000, "detail":True}
plot_train_loss(**args)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# For the Experiment 2 results
args["ckpt_dir"] = './results/disent/attention_factorvae/'
#plot_experiment2(args.get("ckpt_dir"), args.get("seeds"))
plot_training_loss(args.get("ckpt_dir"), args.get("seeds"), detail=True)

args = {"ckpt_dir":'./results/disent/attention_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[5,10,15,20,25,30,35,40,45,50], "lambdas":[1.0], "max_iters":150000, "comp_plot":False}
#plot_disentanglemet(**args)
args = {"ckpt_dir":'./results/disent/attention_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[5,10,15,20,25,30,35,40,45,50], "lambdas":[1.0], "max_iters":150000, "detail":True}
plot_train_loss(**args)

# %%
# From experiment 3
args = {"ckpt_dir":'./results/disent/attention_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[10,20,30,40,50], "lambdas":[0.5,1.0,1.5], "max_iters":150000, "comp_plot":False}
plot_disentanglemet(**args)
args = {"ckpt_dir":'./results/disent/attention_factorvae/',"seeds":['seed_1','seed_2'], "gammas":[10,20,30,40,50], "lambdas":[0.5,1.0,1.5], "max_iters":150000, "detail":True}
plot_train_loss(**args)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
